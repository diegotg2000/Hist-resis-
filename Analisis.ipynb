# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(9,6))

I=np.loadtxt('nucleoOx1.txt', usecols=0)
Phi=np.loadtxt('nucleoOx1.txt', usecols=1)

I=I-np.mean(I)
Phi=Phi-np.mean(Phi)

#H=NI/L Phi=NAB --> B=Phi/(NA)

H=N*I/L
B=Phi/(N*A)


plt.plot(H,B)
plt.xlabel('H (A/m)', fontsize=15)
plt.ylabel('B (T)', fontsize=15)
# Out:
# Text(0, 0.5, 'B (T)')

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(12,8))
#ORDEN= 1,4,2,3
NOMBRES = np.array(['nucleoOx1.txt', 'nucleoOx4.txt', 'nucleoOx2.txt', 'nucleoOx3.txt'])
DATOS = np.array(['f=0.1Hz, V=1V','f=0.2, V=1V','f=0.2Hz, V=2V','f=0.3Hz, V=2V'])
AREAS = np.array([0.131,0.076,0.202,0.157])
for nombre in NOMBRES:
    i=np.where(NOMBRES==nombre)[0][0]
    
    I=np.loadtxt(nombre, usecols=0)
    Phi=np.loadtxt(nombre, usecols=1)

    I=I-np.mean(I)
    Phi=Phi-np.mean(Phi)

    #H=NI/L Phi=NAB --> B=Phi/(NA)

    H=N*I/L
    B=Phi/(N*A)

    plt.subplot(2,2,i+1)
    plt.plot(H,B, label=DATOS[i], c='blue')
    if i>1:
        plt.xlabel('H (A/m)', fontsize=15)
    if i%2 ==0:
        plt.ylabel('B (T)', fontsize=15)
    plt.axis([-4550,4550,-1,1])
    plt.text(2000,-0.5, 'E='+str(AREAS[i])+' J', fontsize=13)
    plt.legend()

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(7,5))

I=np.loadtxt('nucleoInutil.txt', usecols=0)
Phi=np.loadtxt('nucleoInutil.txt', usecols=1)

I=I-np.mean(I)
Phi=Phi-np.mean(Phi)

#H=NI/L Phi=NAB --> B=Phi/(NA)

H=N*I/L
B=Phi/(N*A)


plt.plot(H,B, label='f=0.1Hz, V=3V', c='blue')
plt.xlabel('H (A/m)', fontsize=15)
plt.ylabel('B (T)', fontsize=15)
plt.text(2000,-0.5, 'E='+str(0.958)+' J', fontsize=13)
plt.legend()

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(9,6))

I=np.loadtxt('nucleoOxSierra.txt', usecols=0)
Phi=np.loadtxt('nucleoOxSierra.txt', usecols=1)

I=I-np.mean(I)
Phi=Phi-np.mean(Phi)

#H=NI/L Phi=NAB --> B=Phi/(NA)

H=N*I/L
B=Phi/(N*A)


plt.plot(H,B)
plt.xlabel('H (A/m)', fontsize=15)
plt.ylabel('B (T)', fontsize=15)
# Out:
# Text(0, 0.5, 'B (T)')
