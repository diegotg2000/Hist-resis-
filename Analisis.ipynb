# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(9,6))

I=np.loadtxt('nucleoOx1.txt', usecols=0)
Phi=np.loadtxt('nucleoOx1.txt', usecols=1)

I=I-np.mean(I)
Phi=Phi-np.mean(Phi)

#H=NI/L Phi=NAB --> B=Phi/(NA)

H=N*I/L
B=Phi/(N*A)


plt.plot(B,H)
plt.xlabel('H (A/m)', fontsize=15)
plt.ylabel('B (T)', fontsize=15)
# Out:
# Text(0, 0.5, 'B (T)')

# %%
N=500
L=0.072
A=0.0016

plt.figure(figsize=(9,6))

NOMBRES = ['nucleoOx1.txt', 'nucleoOx2.txt', 'nucleoOx3.txt', 'nucleoOx4.txt','nucleoOxSierra.txt', 'nucleoInutil.txt']

for nombre in NOMBRES:
    I=np.loadtxt('nucleoOx1.txt', usecols=0)
    Phi=np.loadtxt('nucleoOx1.txt', usecols=1)

    I=I-np.mean(I)
    Phi=Phi-np.mean(Phi)

    #H=NI/L Phi=NAB --> B=Phi/(NA)

    H=N*I/L
    B=Phi/(N*A)


    plt.plot(B,H)
    plt.xlabel('H (A/m)', fontsize=15)
    plt.ylabel('B (T)', fontsize=15)
